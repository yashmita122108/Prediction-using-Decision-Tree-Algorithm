# %% [markdown]
# # Graduate Rotational Internship Program

# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# # Task - 6 : Prediction using Decision Tree Algorithm

# %% [markdown]
# # Author : Yashmita

# %% [markdown]
# **Problem statement**
#
# Create the Decision Tree classifier and visualize it graphically.
#
# The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.

# %% [markdown]
# **Dataset**: https://bit.ly/3kXTdox

# %% [markdown]
# # Step 1 : Import the required libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, accuracy_score
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2 : Extract data from source

# %%
# Forming the iris dataframe
Data = pd.read_csv("Iris.csv")
print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %%
#Top values of dataset
Data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Bottom values of dataset
Data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# # Step 3 : Data Pre-processing

# %%
Data.shape
# Out:
# (150, 6)

# %%
Data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
Data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
Data.drop('Id', axis = 1 , inplace= True)

# %%
Data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Step 4 : Data Visualization on comparing features

# %% [markdown]
# **Visualizing the Box Plot for each feature**

# %%
for cl in Data.columns:
    if Data[cl].dtype != 'object': 
        sns.boxplot(Data[cl])
        plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# **INFERENCE**
#
# This plots can be useful for visualizing the distribution of numeric data to identify outliers and gain insights into the data's central tendency and spread.

# %% [markdown]
# **Visualizing features through Histogram**

# %%
Data.hist()
plt.show()

# %%
for col in Data.columns:
    if Data[col].dtypes != "object":
        sns.boxplot(Data['Species'],Data[col])    
        plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# **INFERENCE**
#
# The corrected code would generate a series of box plots, one for each numeric column in the Data DataFrame, showing how the distribution of each numeric variable varies with different categories of the 'Species' column. This can be useful for visualizing the relationship between categorical and numeric variables and identifying potential patterns or differences.

# %%
print(Data.corr())
sns.heatmap(Data.corr(), annot = True)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
# <AxesSubplot:>

# %% [markdown]
# **Pairplot each feature**

# %%
sns.pairplot(data=Data,hue="Species",palette="colorblind")

# %%
X = Data.drop('Species', axis = 1)
Y = Data['Species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=100)

# %% [markdown]
# # Step 5 : Decision tree - Training the Model

# %%
dtc = DecisionTreeClassifier(criterion = "entropy",random_state =0)
model = dtc.fit(X_train,y_train)
y_predict = dtc.predict(X_test)

# %%
#Saving Model

pickle.dump(dtc, open('model.pkl','wb'))

# %% [markdown]
# # Step 6 : Model Evaluation

# %%
# species count
iris_df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris_df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
X = iris_df.drop(columns=['Species'])
Y = iris_df['Species']

# 70% of dataset will we used for training and rest 30% will be used for testing 
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3)

# %%
# Appying decision tree algorithm on our Dataset

from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

model = model.fit(x_train, y_train)

# %%
print("Accuracy: ", model.score(x_test, y_test)*100)
# Out:
# Accuracy:  93.33333333333333

# %% [markdown]
# # Step 7 : Visualizing Decision Tree Classifier algorithm

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(model,
               feature_names = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],
               class_names = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],
               filled = True,
              rounded = True)
# Out:
# [Text(0.5, 0.9166666666666666, 'PetalLengthCm <= 2.35\ngini = 0.663\nsamples = 105\nvalue = [31, 40, 34]\nclass = Iris-versicolor'),
#  Text(0.3333333333333333, 0.75, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0]\nclass = Iris-setosa'),
#  Text(0.6666666666666666, 0.75, 'PetalWidthCm <= 1.75\ngini = 0.497\nsamples = 74\nvalue = [0, 40, 34]\nclass = Iris-versicolor'),
#  Text(0.5, 0.5833333333333334, 'PetalLengthCm <= 5.35\ngini = 0.13\nsamples = 43\nvalue = [0, 40, 3]\nclass = Iris-versicolor'),
#  Text(0.3333333333333333, 0.4166666666666667, 'PetalWidthCm <= 1.65\ngini = 0.048\nsamples = 41\nvalue = [0, 40, 1]\nclass = Iris-versicolor'),
#  Text(0.16666666666666666, 0.25, 'gini = 0.0\nsamples = 39\nvalue = [0, 39, 0]\nclass = Iris-versicolor'),
#  Text(0.5, 0.25, 'SepalLengthCm <= 5.8\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = Iris-versicolor'),
#  Text(0.3333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-virginica'),
# ...

# %% [markdown]
# **INFERENCE**
#
# The graph of a Decision Tree Classifier algorithm provides a visual representation of how the algorithm makes decisions and predicts classes based on the input features. It's a valuable tool for understanding the model's structure, identifying important features, and assessing the model's performance and potential for overfitting.
